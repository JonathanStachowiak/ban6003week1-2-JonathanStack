# %% [markdown]
# # Week 1: Codespaces Readiness Check
# **BAN 6003 Data Management and Analytics Integration**
#
# Welcome to the first course notebook. This notebook is intentionally short. Its purpose is to confirm that your GitHub Codespaces environment can run Python and import Pandas.
#
# By the end of this notebook, you should be able to:
# - Open a notebook in GitHub Codespaces.
# - Run a code cell.
# - Confirm that Python and Pandas are working.
# - Add a short self-introduction.
# - Save, commit, and push your work to GitHub.

# %% [markdown]
# ## How to Run a Cell
# Click inside the code cell below and press **Shift + Enter**, or simply click play button on top right corner. If you get a prompt window asking which enviroment to run, choose `Python Environments` then `base`.
#
#
# If you see a greeting message and a Pandas version number, your environment is working.

# %%
print("✅ Hello BAN 6003! Your Codespaces environment is working.")

import pandas as pd
print(f"Pandas version : {pd.__version__}")
# Out:
# ✅ Hello BAN 6003! Your Codespaces environment is working.
# Pandas version : 3.0.3

# %% [markdown]
# ## About You
# Edit this markdown cell and replace the prompts below with your own information.
#
# - **Name:** Jonathan Stachowiak
# - **Course section:** BAN6003-001
# - **Prior experience:** I have two years of experience using Python in Jupyter Lab/Jupyter Notebook. I've used Python, M Query, and JavaScript to integrate software through API endpoints (POST, PUT, GET, UPDATE). I also have experience using Node.js to build web application software, along with writing DAX and M Query in Power BI. I've used SQL to build a Supabase database, including database management with policies, RLS, and tables with primary and foreign keys. I use Claude Code as an assistant and want to keep improving my own skills. Lastly, I've used R for data cleaning, transformation, and machine learning in statistical analysis.
# - **One thing I hope to learn in this course:** I want to hone my skills in SQL becasue that is a known gap in my skills. I also want to keep building repetition and skills in programming in general.

# %% [markdown]
# ## A Tiny Python Test
# The cell below creates a variable and prints it. You do not need to understand every detail yet. For now, focus on running the cell and reading the output.

# %%
course = "BAN 6003"
message = "I am ready to start working with data."

print(course)
print(message)
# Out:
# BAN 6003
# I am ready to start working with data.

# %% [markdown]
# ## Save, Commit, and Push
# After you have run the cells and completed the **About You** section, save this notebook.
#
# Then open the Terminal and run:
#
# ```bash
# git add .
# git commit -m "Completed Week 1 setup - Jonathan Stachowiak"
# git push
# ```
#
# You may commit and push more than once. Each push updates your assignment repository.

# %% [markdown]
# ## Week 1 Completion Checklist
# Before you finish, make sure:
#
# - [x] I opened this notebook in GitHub Codespaces.
# - [x] I selected the correct kernel if prompted.
# - [x] I ran the Python/Pandas test cell successfully.
# - [x] I completed the **About You** section.
# - [x] I saved the notebook.
# - [x] I committed and pushed my work to GitHub.
# - [x] I stopped or deleted my Codespace after pushing my work.
